# %%
import os
import warnings
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from dotenv import load_dotenv
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
# Warning 무시
warnings.filterwarnings('ignore', category=UserWarning)

# Seaborn 테마 설정
sns.set_theme(style='whitegrid')

# matplotlib 한글 폰트 설정
os.system('rm -rf ~/.cache/matplotlib')
os.system('fc-cache -fv')

plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] = False
# Out:
# /usr/share/fonts: caching, new cache contents: 0 fonts, 5 dirs
# /usr/share/fonts/cMap: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap: caching, new cache contents: 0 fonts, 5 dirs
# /usr/share/fonts/cmap/adobe-cns1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-gb1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-japan1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-japan2: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-korea1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/opentype: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/opentype/urw-base35: caching, new cache contents: 35 fonts, 0 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 4 dirs
# /usr/share/fonts/truetype/dejavu: caching, new cache contents: 6 fonts, 0 dirs
# /usr/share/fonts/truetype/droid: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/share/fonts/truetype/noto: caching, new cache contents: 3 fonts, 0 dirs
# /usr/share/fonts/type1: caching, new cache contents: 0 fonts, 2 dirs
# /usr/share/fonts/type1/gsfonts: caching, new cache contents: 35 fonts, 0 dirs
# /usr/share/fonts/type1/urw-base35: caching, new cache contents: 35 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/cMap: skipping, looped directory detected
# /usr/share/fonts/cmap: skipping, looped directory detected
# /usr/share/fonts/opentype: skipping, looped directory detected
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/type1: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-cns1: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-gb1: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-japan1: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-japan2: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-korea1: skipping, looped directory detected
# /usr/share/fonts/opentype/urw-base35: skipping, looped directory detected
# /usr/share/fonts/truetype/dejavu: skipping, looped directory detected
# /usr/share/fonts/truetype/droid: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /usr/share/fonts/truetype/noto: skipping, looped directory detected
# /usr/share/fonts/type1/gsfonts: skipping, looped directory detected
# /usr/share/fonts/type1/urw-base35: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# # 데이터 병합

# %%
# 데이터 로드
join_df1 = pd.read_csv('../data/ml_df_join.csv', index_col=0)
join_df2 = pd.read_csv('../data/ml_df_rent_fix.csv', index_col=0)

# 데이터 병합
merge_df = pd.merge(join_df1, join_df2, left_on='상권', right_on='상권')
data = merge_df.dropna()

# 2024년에 대한 칼럼 제거
data = data.loc[:, ~data.columns.str.startswith("2024")]
data.shape
# Out:
# (1377, 2397)

# %% [markdown]
# ## 스케일링

# %%
selected_columns = data.iloc[:, 10:].copy()  # 기존 데이터 복사
additional_columns = data[['x좌표', 'y좌표']]  # 추가할 컬럼 선택

# 📌 새로운 데이터프레임 생성
data1 = pd.concat([selected_columns, additional_columns], axis=1)
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data1)  # 표준화 적용
scaled_data = pd.DataFrame(scaled_data, columns=data1.columns)  # DataFrame 변환
scaled_data.shape
# Out:
# (1377, 2389)

# %% [markdown]
# # PCA

# %%
# 분기 리스트 생성
quarters = [f"{year}{q}" for year in range(2019, 2024) for q in range(1, 5)]

# 결과 저장 딕셔너리
pca_results = {}
loading_results = {}
variance_results = {}

# 분기별로 PCA 수행
for quarter in quarters:
  # 해당 분기에 해당하는 컬럼 선택
  selected_columns = [col for col in scaled_data.columns if col.startswith(quarter)]

  if not selected_columns:  # 해당 분기의 데이터가 없으면 건너뛰기
    continue

  # 데이터 선택
  X = scaled_data[selected_columns]

  # PCA 수행
  pca = PCA()
  X_pca = pca.fit_transform(X)

  # 설명된 분산 비율 계산
  explained_variance_ratio = np.cumsum(pca.explained_variance_ratio_)  # 누적 분산 비율 계산

  # 0.85를 넘는 최소 PC 개수 찾기
  num_components = np.argmax(explained_variance_ratio >= 0.85) + 1

  # 선택된 PC별 설명된 분산 비율 저장
  df_variance = pd.DataFrame({
      "PC": [f"PC{i+1}" for i in range(num_components)],
      "Explained_Variance": pca.explained_variance_ratio_[:num_components]
  })

  # 결과 저장
  variance_results[f"df_variance_{quarter}"] = df_variance

  # 선택된 PC들만 사용하여 새로운 데이터프레임 생성
  df_pca = pd.DataFrame(X_pca[:, :num_components], columns=[f"PC{i+1}" for i in range(num_components)])

  # 결과 저장
  pca_results[f"df_pca_{quarter}"] = df_pca

  # 📌 **각 분기의 로딩값(주성분 계수) 구하기**
  loading_matrix = pca.components_[:num_components].T * np.sqrt(pca.explained_variance_[:num_components])

  # 로딩값 데이터프레임 생성 (컬럼명은 PC1, PC2, ..., 인덱스는 원본 데이터의 컬럼)
  df_loading = pd.DataFrame(loading_matrix, index=selected_columns, columns=[f"PC{i+1}_loading" for i in range(num_components)])

  # 로딩값 결과 저장
  loading_results[f"df_loading_{quarter}"] = df_loading

# 딕셔너리에 저장된 데이터프레임을 개별 변수로 생성
globals().update(pca_results)
globals().update(loading_results)
globals().update(variance_results)

# %% [markdown]
# ## 매출에 대한 우선분석에 대한 근거 확인
# - PC1에서 매출에 해당하는 변수개수를 확인후 출력

# %%
# 매출에 대한 우선분석에 대한 근거 확인
# PC1에서 매출에 해당하는 변수개수를 확인후 출력

df_list = []

for year in range(2019, 2024):
  for quart in range(1, 5):
    df_name = f"df_loading_{year}{quarter}"
    if df_name in globals():
      df = globals()[df_name].copy()
      df = df.set_index(df.columns[0])
      df["Period"] = f"{year}Q{quarter}"
      df_list.append(df)

# 최대 20개 행을 유지하는 빈 데이터프레임 생성
total_df = pd.DataFrame(index=range(20))

for year in range(2019, 2024):
  for quarter in range(1, 5):
    df_name = f"df_loading_{year}{quarter}"

    if df_name in globals():  # 존재하는 데이터프레임만 처리
      df = globals()[df_name].copy().sort_values(by='PC1_loading', ascending=False)
      df = df.reset_index().head(20)  # 상위 20개 행 선택

      col_name = f"{year}{quarter}_PC1"  # 컬럼명 지정

      # 기존 total_df 크기를 유지하면서 새로운 컬럼 추가
      total_df[col_name] = pd.Series(df['index'].values[:20], index=range(20))

# 각 칼럼에서 "점포"라는 단어가 포함된 셀 개수 카운트
store_counts = total_df.apply(lambda col: col.astype(str).str.contains("매출").sum())
store_counts
# Out:
# 20191_PC1    19
# 20192_PC1    20
# 20193_PC1    20
# 20194_PC1    19
# 20201_PC1    19
# 20202_PC1    18
# 20203_PC1    19
# 20204_PC1    19
# 20211_PC1    19
# 20212_PC1    19
# 20213_PC1    19
# 20214_PC1    19
# 20221_PC1    19
# 20222_PC1    19
# 20223_PC1    19
# 20224_PC1    19
# 20231_PC1    19
# 20232_PC1    19
# 20233_PC1    19
# 20234_PC1    19
# dtype: int64

# %%
total_df
# Out:
#            20191_PC1         20192_PC1         20193_PC1         20194_PC1  \
# 0       20191금요일매출건수       20192남성매출건수       20193남성매출건수    20194연령대30매출건수
# 1       20191목요일매출건수      20192금요일매출건수      20193금요일매출건수      20194금요일매출건수
# 2        20191주중매출건수       20192당월매출건수       20193당월매출건수       20194남성매출건수
# 3       20191수요일매출건수  20192시간대건수21매출건수      20193목요일매출건수       20194당월매출건수
# 4        20191당월매출건수      20192토요일매출건수  20193시간대건수21매출건수      20194수요일매출건수
# 5       20191화요일매출건수      20192목요일매출건수      20193수요일매출건수      20194목요일매출건수
# 6       20191월요일매출건수       20192주중매출건수       20193주중매출건수       20194주중매출건수
# 7        20191남성매출건수    20192연령대30매출건수      20193화요일매출건수      20194화요일매출건수
# 8     20191연령대30매출건수      20192수요일매출건수      20193토요일매출건수  20194시간대건수21매출건수
# 9   20191시간대건수14매출건수  20192시간대건수17매출건수  20193시간대건수17매출건수  20194시간대건수14매출건수
# 10  20191시간대건수17매출건수       20192주말매출건수      20193월요일매출건수  20194시간대건수17매출건수
# 11  20191시간대건수21매출건수    20192연령대20매출금액    20193연령대30매출건수      20194월요일매출건수
# 12       20191여성매출건수    20192연령대50매출건수       20193주말매출건수    20194연령대40매출건수
# 13    20191연령대40매출건수      20192화요일매출건수    20193연령대50매출건수       20194여성매출건수
# 14  20191시간대건수11매출건수      20192월요일매출건수    20193연령대20매출금액      20194토요일매출건수
# 15    20191연령대50매출건수       20192여성매출건수       20193여성매출건수     20194프랜차이즈점포수
# 16      20191토요일매출건수       20192여성매출금액       20193여성매출금액    20194연령대50매출건수
# 17    20191연령대20매출금액  20192시간대건수14매출건수  20193시간대건수14매출건수  20194시간대2124매출금액
# 18       20191주말매출건수    20192연령대40매출건수    20193연령대40매출건수       20194주말매출건수
# 19     20191프랜차이즈점포수      20192일요일매출건수      20193일요일매출건수    20194연령대20매출금액
#
#            20201_PC1         20202_PC1         20203_PC1         20204_PC1  \
# 0       20201금요일매출건수      20202금요일매출건수       20203남성매출건수    20204연령대30매출건수
# 1       20201수요일매출건수    20202연령대30매출건수      20203금요일매출건수      20204목요일매출건수
# 2        20201주중매출건수      20202목요일매출건수    20203연령대30매출건수       20204주중매출건수
# 3        20201남성매출건수       20202남성매출건수      20203목요일매출건수       20204남성매출건수
# 4        20201당월매출건수       20202주중매출건수       20203주중매출건수      20204수요일매출건수
# 5     20201연령대30매출건수       20202당월매출건수       20203당월매출건수       20204당월매출건수
# 6       20201목요일매출건수      20202수요일매출건수      20203화요일매출건수      20204화요일매출건수
# 7       20201화요일매출건수      20202화요일매출건수      20203수요일매출건수      20204금요일매출건수
# 8       20201월요일매출건수      20202월요일매출건수      20203월요일매출건수      20204월요일매출건수
# 9   20201시간대건수14매출건수  20202시간대건수14매출건수  20203시간대건수14매출건수  20204시간대건수14매출건수
# 10  20201시간대건수21매출건수  20202시간대건수21매출건수  20203시간대건수21매출건수    20204연령대40매출건수
# 11       20201여성매출건수    20202연령대40매출건수    20203연령대40매출건수  20204시간대건수11매출건수
# 12    20201연령대40매출건수  20202시간대건수11매출건수  20203시간대건수17매출건수  20204시간대건수21매출건수
# 13  20201시간대건수17매출건수  20202시간대건수17매출건수  20203시간대건수11매출건수  20204시간대건수17매출건수
# 14  20201시간대건수11매출건수       20202여성매출건수    20203연령대50매출건수       20204여성매출건수
# 15    20201연령대50매출건수    20202연령대50매출건수       20203여성매출건수    20204연령대20매출금액
# 16     20201프랜차이즈점포수    20202연령대20매출금액    20203연령대20매출금액  20204시간대2124매출금액
# 17      20201토요일매출건수     20202프랜차이즈점포수     20203프랜차이즈점포수    20204연령대50매출건수
# 18    20201연령대20매출금액      20202토요일매출건수  20203시간대2124매출금액     20204프랜차이즈점포수
# 19       20201주말매출건수        20202개업점포수      20203토요일매출건수       20204여성매출금액
#
#            20211_PC1         20212_PC1         20213_PC1         20214_PC1  \
# 0     20211연령대30매출건수      20212금요일매출건수       20213남성매출건수      20214금요일매출건수
# 1       20211금요일매출건수       20212남성매출건수      20213금요일매출건수       20214남성매출건수
# 2        20211주중매출건수    20212연령대30매출건수       20213주중매출건수    20214연령대30매출건수
# 3        20211남성매출건수       20212주중매출건수      20213수요일매출건수       20214주중매출건수
# 4       20211목요일매출건수      20212목요일매출건수      20213화요일매출건수      20214목요일매출건수
# 5       20211수요일매출건수      20212수요일매출건수       20213당월매출건수       20214당월매출건수
# 6        20211당월매출건수       20212당월매출건수    20213연령대30매출건수      20214수요일매출건수
# 7       20211화요일매출건수      20212화요일매출건수      20213목요일매출건수      20214화요일매출건수
# 8       20211월요일매출건수      20212월요일매출건수      20213월요일매출건수      20214월요일매출건수
# 9     20211연령대40매출건수  20212시간대건수14매출건수  20213시간대건수21매출건수    20214연령대40매출건수
# 10  20211시간대건수14매출건수  20212시간대건수21매출건수    20213연령대40매출건수  20214시간대건수21매출건수
# 11  20211시간대건수21매출건수    20212연령대40매출건수  20213시간대건수14매출건수  20214시간대건수14매출건수
# 12  20211시간대건수11매출건수  20212시간대건수11매출건수  20213시간대건수11매출건수  20214시간대건수11매출건수
# 13       20211여성매출건수  20212시간대건수17매출건수  20213시간대건수17매출건수       20214여성매출건수
# 14  20211시간대건수17매출건수       20212여성매출건수       20213여성매출건수  20214시간대건수17매출건수
# 15  20211시간대2124매출금액    20212연령대50매출건수    20213연령대50매출건수    20214연령대50매출건수
# 16    20211연령대50매출건수     20212프랜차이즈점포수     20213프랜차이즈점포수     20214프랜차이즈점포수
# 17    20211연령대20매출금액    20212연령대20매출금액      20213토요일매출건수    20214연령대20매출금액
# 18     20211프랜차이즈점포수  20212시간대2124매출금액    20213연령대20매출금액       20214여성매출금액
# 19       20211여성매출금액       20212여성매출금액       20213주말매출건수  20214시간대2124매출금액
#
#            20221_PC1         20222_PC1         20223_PC1         20224_PC1  \
# 0       20221금요일매출건수      20222금요일매출건수       20223남성매출건수      20224금요일매출건수
# 1        20221남성매출건수       20222남성매출건수      20223금요일매출건수       20224주중매출건수
# 2       20221화요일매출건수       20222당월매출건수       20223주중매출건수       20224남성매출건수
# 3        20221주중매출건수       20222주중매출건수      20223목요일매출건수      20224목요일매출건수
# 4        20221당월매출건수      20222수요일매출건수      20223월요일매출건수      20224월요일매출건수
# 5     20221연령대30매출건수      20222목요일매출건수       20223당월매출건수      20224수요일매출건수
# 6       20221수요일매출건수    20222연령대30매출건수      20223수요일매출건수       20224당월매출건수
# 7       20221목요일매출건수      20222화요일매출건수      20223화요일매출건수      20224화요일매출건수
# 8       20221월요일매출건수      20222월요일매출건수    20223연령대30매출건수    20224연령대30매출건수
# 9   20221시간대건수21매출건수  20222시간대건수21매출건수    20223연령대40매출건수    20224연령대40매출건수
# 10    20221연령대40매출건수    20222연령대40매출건수  20223시간대건수21매출건수  20224시간대건수14매출건수
# 11  20221시간대건수14매출건수       20222여성매출건수       20223여성매출건수       20224여성매출건수
# 12  20221시간대건수11매출건수  20222시간대건수14매출건수  20223시간대건수14매출건수  20224시간대건수11매출건수
# 13       20221여성매출건수  20222시간대건수11매출건수    20223연령대50매출건수  20224시간대건수21매출건수
# 14  20221시간대건수17매출건수  20222시간대건수17매출건수  20223시간대건수17매출건수    20224연령대50매출건수
# 15    20221연령대50매출건수    20222연령대50매출건수  20223시간대건수11매출건수  20224시간대건수17매출건수
# 16     20221프랜차이즈점포수     20222프랜차이즈점포수     20223프랜차이즈점포수     20224프랜차이즈점포수
# 17    20221연령대20매출금액       20222여성매출금액    20223연령대20매출건수    20224연령대20매출건수
# 18  20221시간대2124매출금액      20222토요일매출건수    20223연령대30매출금액       20224여성매출금액
# 19       20221여성매출금액       20222주말매출건수       20223여성매출금액    20224연령대20매출금액
#
#            20231_PC1         20232_PC1         20233_PC1         20234_PC1
# 0       20231금요일매출건수      20232금요일매출건수      20233금요일매출건수      20234금요일매출건수
# 1       20231수요일매출건수       20232남성매출건수       20233남성매출건수       20234남성매출건수
# 2        20231주중매출건수       20232주중매출건수       20233주중매출건수       20234주중매출건수
# 3        20231남성매출건수       20232당월매출건수      20233목요일매출건수      20234목요일매출건수
# 4       20231화요일매출건수      20232화요일매출건수      20233수요일매출건수      20234수요일매출건수
# 5       20231목요일매출건수      20232목요일매출건수      20233화요일매출건수      20234화요일매출건수
# 6        20231당월매출건수      20232수요일매출건수       20233당월매출건수      20234월요일매출건수
# 7       20231월요일매출건수      20232월요일매출건수      20233월요일매출건수       20234당월매출건수
# 8     20231연령대30매출건수    20232연령대30매출건수    20233연령대30매출건수    20234연령대30매출건수
# 9     20231연령대40매출건수    20232연령대40매출건수    20233연령대40매출건수  20234시간대건수14매출건수
# 10  20231시간대건수14매출건수  20232시간대건수14매출건수  20233시간대건수14매출건수    20234연령대40매출건수
# 11       20231여성매출건수       20232여성매출건수  20233시간대건수21매출건수  20234시간대건수11매출건수
# 12  20231시간대건수11매출건수  20232시간대건수21매출건수       20233여성매출건수  20234시간대건수21매출건수
# 13  20231시간대건수21매출건수  20232시간대건수11매출건수  20233시간대건수11매출건수    20234연령대50매출건수
# 14    20231연령대50매출건수    20232연령대50매출건수    20233연령대50매출건수       20234여성매출건수
# 15    20231연령대30매출금액  20232시간대건수17매출건수    20233연령대30매출금액     20234프랜차이즈점포수
# 16     20231프랜차이즈점포수     20232프랜차이즈점포수  20233시간대건수17매출건수  20234시간대건수17매출건수
# 17  20231시간대건수17매출건수    20232연령대30매출금액     20233프랜차이즈점포수  20234시간대2124매출금액
# 18       20231여성매출금액       20232여성매출금액       20233여성매출금액       20234여성매출금액
# 19  20231시간대2124매출금액      20232토요일매출건수    20233연령대20매출건수    20234연령대20매출건수

# %%
# 한번 이쁘게 시각화

plt.figure(figsize=(10, 4))
sns.barplot(store_counts)
plt.xticks(rotation=45)
plt.title('PC1별 TOP20의 매출 관련 변수 개수')
plt.ylim((10, 22))
plt.show()

# %% [markdown]
# # 군집분석
# ## k-means

# %%
# 클러스터링 결과 저장 딕셔너리
final_cluster_results = {}

# globals()에서 df_pca_* 형태의 데이터프레임 찾기
pca_dfs = {key: value for key, value in globals().items() if key.startswith("df_pca_")}

# 각 df_pca_{quarter}에 대해 KMeans 클러스터링 수행 (K=3 고정)
for quarter, df_pca in pca_dfs.items():
  if df_pca.empty:  # 데이터가 비어 있는 경우 스킵
    print(f"{quarter} 데이터가 비어 있음. 건너뜀.")
    continue

  # print(f"{quarter} - PCA 데이터 크기: {df_pca.shape}")

  #  NaN이 있으면 제거
  if df_pca.isna().sum().sum() > 0:
    print(f"{quarter}: NaN 값이 존재. 제거 후 진행.")
    df_pca = df_pca.dropna()

  if df_pca.shape[0] < 3:  # 최소 3개 샘플 이상 필요
    print(f"{quarter}: 데이터가 너무 적어 KMeans 수행 불가. 건너뜀.")
    continue

  # K=3으로 KMeans 클러스터링 수행
  kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)
  cluster_labels = kmeans.fit_predict(df_pca)

  # 클러스터링 결과 데이터프레임 생성
  df_cluster = df_pca.copy()
  df_cluster["Cluster"] = cluster_labels

  # "df_pca_"를 제거한 올바른 데이터프레임 이름 생성
  quarter_name = quarter.replace("df_pca_", "")
  final_cluster_results[f"df_4cluster_{quarter_name}"] = df_cluster

# %%
# final_cluster_results에 저장된 데이터프레임을 개별 변수로 생성
for name, df in final_cluster_results.items():
  globals()[name] = df

# 저장된 데이터프레임 목록 확인
print("생성된 개별 데이터프레임 목록:", list(final_cluster_results.keys()))
# Out:
# 생성된 개별 데이터프레임 목록: ['df_4cluster_20191', 'df_4cluster_20192', 'df_4cluster_20193', 'df_4cluster_20194', 'df_4cluster_20201', 'df_4cluster_20202', 'df_4cluster_20203', 'df_4cluster_20204', 'df_4cluster_20211', 'df_4cluster_20212', 'df_4cluster_20213', 'df_4cluster_20214', 'df_4cluster_20221', 'df_4cluster_20222', 'df_4cluster_20223', 'df_4cluster_20224', 'df_4cluster_20231', 'df_4cluster_20232', 'df_4cluster_20233', 'df_4cluster_20234']

# %%
# 각 데이터 프레임의 각 상권의 칼럼 붙여주기
for year in range(2019, 2024):
  for quart in range(1, 5):
    quarter_key = f'df_4cluster_{year}{quart}'
    cluster_df = globals()[quarter_key].copy()

    # data['상권'] 컬럼 추가
    cluster_df['상권'] = data['상권']

    # 새로운 변수명으로 저장
    new_key = f'cluster_df_{year}{quart}'
    globals()[new_key] = cluster_df

# %%
cluster_df_20191
# Out:
#            PC1       PC2       PC3       PC4  Cluster                    상권
# 0    -0.676738  3.134349 -0.529508 -0.822720        0       배화여자대학교(박노수미술관)
# 1    -0.540788 -0.766346 -0.242808  1.280549        1     세종마을음식문화거리(금천교시장)
# 2    -2.656878 -1.959457 -0.076684  0.203376        1                  통인시장
# 3    -2.957838 -1.373154  0.118826  0.053731        1          동묘시장(동묘벼룩시장)
# 4     2.606929 -2.581391 -2.684357  0.627921        1  동대문문구완구거리(동대문문구완구시장)
# ...        ...       ...       ...       ...      ...                   ...
# 1372 -3.494871 -1.856278  0.347977 -0.030590        1                언북초등학교
# 1373 -3.550110 -1.871832  0.137295  0.148438        1                   NaN
# 1374 -2.216806 -2.746278 -0.176935  0.835878        1                 언주중학교
# 1375 -3.012576 -1.764277 -0.056877  0.172801        1                언주역 6번
# 1376 -3.100855 -2.627123  0.263747  0.462704        1           역삼월드메르디앙아파트
#
# [1377 rows x 6 columns]

# %% [markdown]
# # 진짜 시작

# %% [markdown]
# ## 클러스터 군집 확인이 필요
# 1. 클러스터별 비율이 같은거는 거의 확인이 끝남.
# 2. 각 클러스터를 비율별로 옮기기
# 3. df4cluster_{year}{quart} <- 이런식으로 변수가 되어있음

# %%
chnage_cluster = pd.DataFrame(df_4cluster_20191['Cluster'].value_counts())
chnage_cluster = chnage_cluster.sort_values(by='count')
chnage_cluster
# Out:
#          count
# Cluster
# 2            5
# 3           44
# 0          327
# 1         1001

# %% [markdown]
# 가장 개수가 낮은 순서로 0 1 2 3으로 클러스터를 바꿀꺼임

# %%
join_cluster = chnage_cluster.reset_index().reset_index()[['index', 'Cluster']]
join_cluster
# Out:
#    index  Cluster
# 0      0        2
# 1      1        3
# 2      2        0
# 3      3        1

# %%
pd.merge(cluster_df_20191, join_cluster, left_on='Cluster', right_on='Cluster').drop('Cluster', axis=1).rename(columns={'index': 'cluster'})
# Out:
#            PC1       PC2       PC3       PC4                    상권  cluster
# 0    -0.676738  3.134349 -0.529508 -0.822720       배화여자대학교(박노수미술관)        2
# 1    -0.540788 -0.766346 -0.242808  1.280549     세종마을음식문화거리(금천교시장)        3
# 2    -2.656878 -1.959457 -0.076684  0.203376                  통인시장        3
# 3    -2.957838 -1.373154  0.118826  0.053731          동묘시장(동묘벼룩시장)        3
# 4     2.606929 -2.581391 -2.684357  0.627921  동대문문구완구거리(동대문문구완구시장)        3
# ...        ...       ...       ...       ...                   ...      ...
# 1372 -3.494871 -1.856278  0.347977 -0.030590                언북초등학교        3
# 1373 -3.550110 -1.871832  0.137295  0.148438                   NaN        3
# 1374 -2.216806 -2.746278 -0.176935  0.835878                 언주중학교        3
# 1375 -3.012576 -1.764277 -0.056877  0.172801                언주역 6번        3
# 1376 -3.100855 -2.627123  0.263747  0.462704           역삼월드메르디앙아파트        3
#
# [1377 rows x 6 columns]

# %%
file_name = list(final_cluster_results.keys())
file_name
# Out:
# ['df_4cluster_20191',
#  'df_4cluster_20192',
#  'df_4cluster_20193',
#  'df_4cluster_20194',
#  'df_4cluster_20201',
#  'df_4cluster_20202',
#  'df_4cluster_20203',
#  'df_4cluster_20204',
#  'df_4cluster_20211',
#  'df_4cluster_20212',
#  'df_4cluster_20213',
#  'df_4cluster_20214',
#  'df_4cluster_20221',
#  'df_4cluster_20222',
#  'df_4cluster_20223',
#  'df_4cluster_20224',
#  'df_4cluster_20231',
#  'df_4cluster_20232',
#  'df_4cluster_20233',
#  'df_4cluster_20234']

# %%
file_name[1][-5:]
# Out:
# '20192'

# %%
# 빈 데이터프레임 초기화
total_df = pd.DataFrame()

# 파일 불러오기
for file in file_name:
  cluster_df = globals()[file]

  # 클러스터 변환 작업 그대로
  chnage_cluster = pd.DataFrame(cluster_df['Cluster'].value_counts())
  chnage_cluster = chnage_cluster.sort_values(by='count')
  join_cluster = chnage_cluster.reset_index().reset_index()[['index', 'Cluster']]
  final_df = pd.merge(cluster_df, join_cluster, left_on='Cluster', right_on='Cluster').drop('Cluster', axis=1).rename(columns={'index': 'cluster'})

  final_df = final_df[['cluster']]
  final_df.columns = [f'{file[-5:]}_cluster']
  total_df = pd.concat([total_df, final_df], axis=1)

  # 필드명 조인
total_df['상권'] = data['상권']
total_df

total_df.to_csv('../data/cluster_difference.csv')
